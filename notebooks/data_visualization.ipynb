# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_ACE =  pd.read_pickle('../data/processed/ACE_X.pkl')
df_DSCOVR =  pd.read_pickle('../data/processed/DSCOVR_X.pkl')

# %%
df_ACE.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'ACE_Bx'}>,
#         <AxesSubplot:title={'center':'ACE_By'}>,
#         <AxesSubplot:title={'center':'ACE_Bz'}>],
#        [<AxesSubplot:title={'center':'ACE_x'}>,
#         <AxesSubplot:title={'center':'ACE_y'}>,
#         <AxesSubplot:title={'center':'ACE_z'}>],
#        [<AxesSubplot:title={'center':'ACE_Vx'}>,
#         <AxesSubplot:title={'center':'ACE_Temp'}>,
#         <AxesSubplot:title={'center':'MMS_x'}>],
#        [<AxesSubplot:title={'center':'MMS_y'}>,
#         <AxesSubplot:title={'center':'MMS_z'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_DSCOVR.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'ACE_Bx'}>,
#         <AxesSubplot:title={'center':'ACE_By'}>,
#         <AxesSubplot:title={'center':'ACE_Bz'}>],
#        [<AxesSubplot:title={'center':'ACE_x'}>,
#         <AxesSubplot:title={'center':'ACE_y'}>,
#         <AxesSubplot:title={'center':'ACE_z'}>],
#        [<AxesSubplot:title={'center':'ACE_Vx'}>,
#         <AxesSubplot:title={'center':'ACE_Temp'}>,
#         <AxesSubplot:title={'center':'MMS_x'}>],
#        [<AxesSubplot:title={'center':'MMS_y'}>,
#         <AxesSubplot:title={'center':'MMS_z'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
mean_df  = pd.read_pickle('../data/processed/mean_ACE.pkl')
data_y =  pd.read_pickle('../data/processed/ACE_Y_mean2.pkl')
mean_df = pd.concat([mean_df, data_y], axis=1)
corre = mean_df.corr()
fig, ax = plt.subplots(figsize=(10,10))  
sns.heatmap(corre, annot= True, linewidths=1, linecolor='white',ax=ax)
# Out:
# <AxesSubplot:>

# %%
type(mean_df)
mean_df.head()
# Out:
#      ACE_Bx    ACE_By    ACE_Bz        ACE_x          ACE_y          ACE_z  \
# 0 -4.556196  4.864964  2.709517  1504302.250 -215788.640625  152330.000000
# 1 -4.681481  4.749075  2.674562  1504300.875 -215791.656250  152329.609375
# 2 -4.779902  4.659590  2.673720  1504299.375 -215794.671875  152329.203125
# 3 -4.872654  4.577725  2.655009  1504298.000 -215797.687500  152328.812500
# 4 -4.954689  4.476873  2.662764  1504296.625 -215800.734375  152328.453125
#
#        ACE_Vx       ACE_Temp         MMS_x         MMS_y         MMS_z  \
# 0 -463.301788  103634.148438  94185.304688  15990.543945  18063.023438
# 1 -463.233246  105357.445312  94273.046875  16051.230469  18094.318359
# 2 -463.088654  107281.781250  94360.640625  16111.890625  18125.587891
# 3 -463.042877  109175.414062  94448.093750  16172.522461  18156.828125
# 4 -462.995819  111064.304688  94535.398438  16233.127930  18188.039062
#
#          Delay
# 0      [59.25]
# 1       [59.0]
# 2      [58.25]
# 3      [57.75]
# ...

# %%
mean_df['Delay'] =  mean_df['Delay'].values
mean_df.head()
# Out:
#      ACE_Bx    ACE_By    ACE_Bz        ACE_x          ACE_y          ACE_z  \
# 0 -4.556196  4.864964  2.709517  1504302.250 -215788.640625  152330.000000
# 1 -4.681481  4.749075  2.674562  1504300.875 -215791.656250  152329.609375
# 2 -4.779902  4.659590  2.673720  1504299.375 -215794.671875  152329.203125
# 3 -4.872654  4.577725  2.655009  1504298.000 -215797.687500  152328.812500
# 4 -4.954689  4.476873  2.662764  1504296.625 -215800.734375  152328.453125
#
#        ACE_Vx       ACE_Temp         MMS_x         MMS_y         MMS_z  \
# 0 -463.301788  103634.148438  94185.304688  15990.543945  18063.023438
# 1 -463.233246  105357.445312  94273.046875  16051.230469  18094.318359
# 2 -463.088654  107281.781250  94360.640625  16111.890625  18125.587891
# 3 -463.042877  109175.414062  94448.093750  16172.522461  18156.828125
# 4 -462.995819  111064.304688  94535.398438  16233.127930  18188.039062
#
#          Delay
# 0      [59.25]
# 1       [59.0]
# 2      [58.25]
# 3      [57.75]
# ...
